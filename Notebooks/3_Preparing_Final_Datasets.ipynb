# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# **Let's work with the mean encoded dataset as many of the categorical features are ordinal but I do not have the domain knowledge to rank them correctly. Hence it's better to let the SalePrice rank the categorical features**

# %%
cleaned_path = r'C:\Users\Ben\Desktop\Data Science\Kaggle\Advanced-House-Price-Prediction-Kaggle-Competition\Preprocessed_data\mean_encoded.csv'
target_path = r'C:\Users\Ben\Desktop\Data Science\Kaggle\Advanced-House-Price-Prediction-Kaggle-Competition\Preprocessed_data\target.csv'

# %%
target = pd.read_csv(target_path)

# %%
target.head(10)
# Out:
#    SalePrice
# 0  12.247699
# 1  12.109016
# 2  12.317171
# 3  11.849405
# 4  12.429220
# 5  11.870607
# 6  12.634606
# 7  12.206078
# 8  11.774528
# 9  11.678448

# %%
target.shape
# Out:
# (1456, 1)

# %%
raw_df = pd.read_csv(cleaned_path)

# %%
raw_df.head(10)
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
# 5          50         85.0    14115            5            5       1993
# 6          20         75.0    10084            8            5       2004
# 7          60         69.0    10382            7            6       1973
# 8          50         51.0     6120            7            5       1931
# 9         190         50.0     7420            5            6       1939
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0       706.0         0.0      150.0        856.0
# ...

# %%
raw_df.shape
# Out:
# (2915, 79)

# %%
df_train = raw_df.iloc[:target.shape[0], :]
df_test = raw_df.iloc[target.shape[0]:, :]

# %%
print(df_train.shape)
print(df_test.shape)
# Out:
# (1456, 79)
# (1459, 79)

# %%
df_train['SalePrice'] = target['SalePrice']

# %%
df_train.tail()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1451          60         62.0     7917            6            5       1999
# 1452          20         85.0    13175            6            6       1978
# 1453          70         66.0     9042            7            9       1941
# 1454          20         68.0     9717            5            6       1950
# 1455          20         75.0     9937            5            6       1965
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 1451          2000         0.0         0.0         0.0      953.0
# 1452          1988       119.0       790.0       163.0      589.0
# 1453          2006         0.0       275.0         0.0      877.0
# 1454          1996         0.0        49.0      1029.0        0.0
# 1455          1965         0.0       830.0       290.0      136.0
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# ...

# %%
df_train.shape
# Out:
# (1456, 80)

# %%
df_test.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 1456          20         80.0    11622            5            6       1961
# 1457          20         81.0    14267            6            6       1958
# 1458          60         74.0    13830            5            5       1997
# 1459          60         78.0     9978            6            6       1998
# 1460         120         43.0     5005            8            5       1992
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  \
# 1456          1961         0.0       468.0       144.0      270.0
# 1457          1958       108.0       923.0         0.0      406.0
# 1458          1998         0.0       791.0         0.0      137.0
# 1459          1998        20.0       602.0         0.0      324.0
# 1460          1992         0.0       263.0         0.0     1017.0
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  \
# ...

# %%
df_test.shape
# Out:
# (1459, 79)

# %%
df_train.to_csv(r'C:\Users\Ben\Desktop\Data Science\Kaggle\Advanced-House-Price-Prediction-Kaggle-Competition\Preprocessed_data\preprocessed_train.csv', index = False)

# %%
df_test.to_csv(r'C:\Users\Ben\Desktop\Data Science\Kaggle\Advanced-House-Price-Prediction-Kaggle-Competition\Preprocessed_data\preprocessed_test.csv', index = False)
