# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
from sklearn.linear_model import LinearRegression

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
train_path = r'C:\Users\Ben\Desktop\Data Science\Kaggle\Advanced House Price Prediction\Data\train.csv'
test_path = r'C:\Users\Ben\Desktop\Data Science\Kaggle\Advanced House Price Prediction\Data\test.csv'

# %%
df_raw_train = pd.read_csv(train_path)
df_raw_test = pd.read_csv(test_path)

# %%
df_raw_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_raw_train.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_raw_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_raw_test.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1454         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1455         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1456         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1458         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
print(df_raw_train.shape)
print(df_raw_test.shape)
# Out:
# (1460, 81)
# (1459, 80)

# %%
df_raw = pd.concat([df_raw_train, df_raw_test], axis = 0)

# %%
df_raw.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_raw.shape
# Out:
# (2919, 81)

# %%
df = df_raw.copy()

# %%
df = df.drop(['Id', 'SalePrice'], axis = 1)

# %%
df = df.reset_index(drop = 'True')

# %%
df.shape
# Out:
# (2919, 79)

# %%
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# ...

# %%
df.tail()
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 2914         160       RM         21.0     1936   Pave   NaN      Reg
# 2915         160       RM         21.0     1894   Pave   NaN      Reg
# 2916          20       RL        160.0    20000   Pave   NaN      Reg
# 2917          85       RL         62.0    10441   Pave   NaN      Reg
# 2918          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 2914         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 2915         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 2916         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 2917         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 2918         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.describe().T
# Out:
#                 count          mean          std     min     25%     50%  \
# MSSubClass     2919.0     57.137718    42.517628    20.0    20.0    50.0
# LotFrontage    2433.0     69.305795    23.344905    21.0    59.0    68.0
# LotArea        2919.0  10168.114080  7886.996359  1300.0  7478.0  9453.0
# OverallQual    2919.0      6.089072     1.409947     1.0     5.0     6.0
# OverallCond    2919.0      5.564577     1.113131     1.0     5.0     5.0
# YearBuilt      2919.0   1971.312778    30.291442  1872.0  1953.5  1973.0
# YearRemodAdd   2919.0   1984.264474    20.894344  1950.0  1965.0  1993.0
# MasVnrArea     2896.0    102.201312   179.334253     0.0     0.0     0.0
# BsmtFinSF1     2918.0    441.423235   455.610826     0.0     0.0   368.5
# BsmtFinSF2     2918.0     49.582248   169.205611     0.0     0.0     0.0
# BsmtUnfSF      2918.0    560.772104   439.543659     0.0   220.0   467.0
# TotalBsmtSF    2918.0   1051.777587   440.766258     0.0   793.0   989.5
# ...

# %%
df.describe(include = 'object').T
# Out:
#               count unique      top  freq
# MSZoning       2915      5       RL  2265
# Street         2919      2     Pave  2907
# Alley           198      2     Grvl   120
# LotShape       2919      4      Reg  1859
# LandContour    2919      4      Lvl  2622
# Utilities      2917      2   AllPub  2916
# LotConfig      2919      5   Inside  2133
# LandSlope      2919      3      Gtl  2778
# Neighborhood   2919     25    NAmes   443
# Condition1     2919      9     Norm  2511
# Condition2     2919      8     Norm  2889
# BldgType       2919      5     1Fam  2425
# HouseStyle     2919      8   1Story  1471
# RoofStyle      2919      6    Gable  2310
# RoofMatl       2919      8  CompShg  2876
# Exterior1st    2918     15  VinylSd  1025
# Exterior2nd    2918     16  VinylSd  1014
# MasVnrType     2895      4     None  1742
# ExterQual      2919      4       TA  1798
# ExterCond      2919      5       TA  2538
# Foundation     2919      6    PConc  1308
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2919 entries, 0 to 2918
# Data columns (total 79 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   int64
#  1   MSZoning       2915 non-null   object
#  2   LotFrontage    2433 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          198 non-null    object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2917 non-null   object
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
# ...

# %% [markdown]
# # Feature Engineering

# %%
#Method to view heatmap of a correlation matrix dataframe
def heatMap(df):  
    plt.figure(figsize = (20, 15))
    #Creating the correlation matrix
    df = df.corr()
    #Creating dataframe out of the upper triangle of the correlation matrix
    upper = df.where(np.triu(np.ones(df.shape), k=1).astype(np.bool))         
    s = sns.heatmap(upper,
                   annot = True, 
                   cmap = 'RdYlGn',
                   vmin = -1, 
                   vmax = 1)
    s.set_yticklabels(s.get_yticklabels(), rotation = 0, fontsize = 12)
    s.set_xticklabels(s.get_xticklabels(), rotation = 90, fontsize = 12)
    plt.title('Correlation Heatmap')
    plt.show()

# %%
numerical_features = []
categorical_features = []

for column in df.columns:
    if(df[column].dtypes == 'object'):
        categorical_features.append(column)
    else:
        numerical_features.append(column)

# %%
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
numerical_features
# Out:
# ['MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold']

# %% [markdown]
# ## Dealing with Missing Values

# %%
#Method to create missig values DF
def mvDF(df):
    df_mv = pd.DataFrame(data = df.isnull().sum(), columns = ['TotalMissing'])
    df_mv['PercentageMissing'] = np.round(((df_mv['TotalMissing']/df.shape[0])*100), 2)
    return df_mv

# %%
#Method to obtain the numerical and categorical features for different levels of missing values
def mvFeaturesLists(df_mv, threshold, categorical_features, numerical_features):
    mv_features = []
    for idx, row in df_mv.iterrows():
        if(df_mv.loc[idx, 'PercentageMissing']>threshold):
            mv_features.append(idx)
    #Separating numerical & categorical mv_features
    numerical_mv_features = []
    categorical_mv_features = []
    for feat in mv_features:
        if feat in categorical_features:
            categorical_mv_features.append(feat)    
        else:
            numerical_mv_features.append(feat)
    return mv_features, categorical_mv_features, numerical_mv_features

# %%
#Viewing the missing values % for each feature
df_mv = mvDF(df)
df_mv
# Out:
#                TotalMissing  PercentageMissing
# MSSubClass                0               0.00
# MSZoning                  4               0.14
# LotFrontage             486              16.65
# LotArea                   0               0.00
# Street                    0               0.00
# Alley                  2721              93.22
# LotShape                  0               0.00
# LandContour               0               0.00
# Utilities                 2               0.07
# LotConfig                 0               0.00
# LandSlope                 0               0.00
# Neighborhood              0               0.00
# Condition1                0               0.00
# Condition2                0               0.00
# BldgType                  0               0.00
# HouseStyle                0               0.00
# OverallQual               0               0.00
# OverallCond               0               0.00
# YearBuilt                 0               0.00
# ...

# %%
#Method to convert all nan values to none for categorical features
def nanToNone(df, features):
    for feat in features:
        df[feat] = df[feat].fillna("None")
    return df

# %%
#Method to convert all nan values to mean of the feature for numerical features
def nanToMean(df, features):
    for feat in features:
        df[feat] = df[feat].fillna(df[feat].mean())
    return df

# %%
#Method to convert all nan values to mode for categorical features
def nanToMode(df, features):
    for feat in features:
        df[feat] = df[feat].fillna(df[feat].mode()[0])
    return df

# %% [markdown]
# ### Features with high missing values %

# %%
high_mv_features, high_categorical_mv_features, high_numerical_mv_features = mvFeaturesLists(df_mv, 40, categorical_features, numerical_features)

# %%
high_mv_features
# Out:
# ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
high_categorical_mv_features
# Out:
# ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %% [markdown]
# For all these categorical features the description says that nan means the feature doesn't exist, that is it's none!

# %%
#Converting NaN values of categorical features to 'None'
df = nanToNone(df, high_categorical_mv_features)

# %%
high_numerical_mv_features
# Out:
# []

# %% [markdown]
# There are no numerical missing value features in this category

# %%
#Viewing the updated dataframe
df.head(20)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           60       RL         65.0     8450   Pave  None      Reg
# 1           20       RL         80.0     9600   Pave  None      Reg
# 2           60       RL         68.0    11250   Pave  None      IR1
# 3           70       RL         60.0     9550   Pave  None      IR1
# 4           60       RL         84.0    14260   Pave  None      IR1
# 5           50       RL         85.0    14115   Pave  None      IR1
# 6           20       RL         75.0    10084   Pave  None      Reg
# 7           60       RL          NaN    10382   Pave  None      IR1
# 8           50       RM         51.0     6120   Pave  None      Reg
# 9          190       RL         50.0     7420   Pave  None      Reg
# 10          20       RL         70.0    11200   Pave  None      Reg
# 11          60       RL         85.0    11924   Pave  None      IR1
# 12          20       RL          NaN    12968   Pave  None      IR2
# ...

# %%
#Viewing the missing values % for each feature
df_mv = mvDF(df)
df_mv
# Out:
#                TotalMissing  PercentageMissing
# MSSubClass                0               0.00
# MSZoning                  4               0.14
# LotFrontage             486              16.65
# LotArea                   0               0.00
# Street                    0               0.00
# Alley                     0               0.00
# LotShape                  0               0.00
# LandContour               0               0.00
# Utilities                 2               0.07
# LotConfig                 0               0.00
# LandSlope                 0               0.00
# Neighborhood              0               0.00
# Condition1                0               0.00
# Condition2                0               0.00
# BldgType                  0               0.00
# HouseStyle                0               0.00
# OverallQual               0               0.00
# OverallCond               0               0.00
# YearBuilt                 0               0.00
# ...

# %% [markdown]
# ### Features with medium missing values %

# %%
med_mv_features, med_categorical_mv_features, med_numerical_mv_features = mvFeaturesLists(df_mv, 1, categorical_features, numerical_features)

# %%
med_mv_features
# Out:
# ['LotFrontage',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %%
med_categorical_mv_features
# Out:
# ['BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond']

# %% [markdown]
# Once again, for all these categorical features the description says that nan means the feature doesn't exist, that is it's none!

# %%
#Converting NaN values of categorical features to 'None'
df = nanToNone(df, med_categorical_mv_features)

# %%
med_numerical_mv_features
# Out:
# ['LotFrontage', 'GarageYrBlt']

# %% [markdown]
# Let us fill in the numerical features missing values with the mean value of the feature

# %%
#Converting NaN values of numerical features to mean of the feature
df = nanToMean(df, med_numerical_mv_features)

# %%
#Viewing updated dataframe
df.head(20)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           60       RL    65.000000     8450   Pave  None      Reg
# 1           20       RL    80.000000     9600   Pave  None      Reg
# 2           60       RL    68.000000    11250   Pave  None      IR1
# 3           70       RL    60.000000     9550   Pave  None      IR1
# 4           60       RL    84.000000    14260   Pave  None      IR1
# 5           50       RL    85.000000    14115   Pave  None      IR1
# 6           20       RL    75.000000    10084   Pave  None      Reg
# 7           60       RL    69.305795    10382   Pave  None      IR1
# 8           50       RM    51.000000     6120   Pave  None      Reg
# 9          190       RL    50.000000     7420   Pave  None      Reg
# 10          20       RL    70.000000    11200   Pave  None      Reg
# 11          60       RL    85.000000    11924   Pave  None      IR1
# 12          20       RL    69.305795    12968   Pave  None      IR2
# ...

# %%
#Viewing the missing values % for each feature
df_mv = mvDF(df)
df_mv
# Out:
#                TotalMissing  PercentageMissing
# MSSubClass                0               0.00
# MSZoning                  4               0.14
# LotFrontage               0               0.00
# LotArea                   0               0.00
# Street                    0               0.00
# Alley                     0               0.00
# LotShape                  0               0.00
# LandContour               0               0.00
# Utilities                 2               0.07
# LotConfig                 0               0.00
# LandSlope                 0               0.00
# Neighborhood              0               0.00
# Condition1                0               0.00
# Condition2                0               0.00
# BldgType                  0               0.00
# HouseStyle                0               0.00
# OverallQual               0               0.00
# OverallCond               0               0.00
# YearBuilt                 0               0.00
# ...

# %% [markdown]
# ### Features with low missing values %

# %%
low_mv_features, low_categorical_mv_features, low_numerical_mv_features = mvFeaturesLists(df_mv, 0, categorical_features, numerical_features)

# %%
low_mv_features
# Out:
# ['MSZoning',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Electrical',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'KitchenQual',
#  'Functional',
#  'GarageCars',
#  'GarageArea',
#  'SaleType']

# %%
low_categorical_mv_features
# Out:
# ['MSZoning',
#  'Utilities',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'SaleType']

# %% [markdown]
# Looks like for these categorical features NaN does NOT mean none. Hence let's impute the mode value!

# %%
#Converting NaN values of categorical features to mode of the feature
df = nanToMode(df, low_categorical_mv_features)

# %%
low_numerical_mv_features
# Out:
# ['MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'GarageCars',
#  'GarageArea']

# %% [markdown]
# Let us fill in the numerical features missing values with the mean value of the feature

# %%
#Converting NaN values of numerical features to mean of the feature
df = nanToMean(df, low_numerical_mv_features)

# %%
#Viewing updated dataframe
df.head(20)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0           60       RL    65.000000     8450   Pave  None      Reg
# 1           20       RL    80.000000     9600   Pave  None      Reg
# 2           60       RL    68.000000    11250   Pave  None      IR1
# 3           70       RL    60.000000     9550   Pave  None      IR1
# 4           60       RL    84.000000    14260   Pave  None      IR1
# 5           50       RL    85.000000    14115   Pave  None      IR1
# 6           20       RL    75.000000    10084   Pave  None      Reg
# 7           60       RL    69.305795    10382   Pave  None      IR1
# 8           50       RM    51.000000     6120   Pave  None      Reg
# 9          190       RL    50.000000     7420   Pave  None      Reg
# 10          20       RL    70.000000    11200   Pave  None      Reg
# 11          60       RL    85.000000    11924   Pave  None      IR1
# 12          20       RL    69.305795    12968   Pave  None      IR2
# ...

# %%
#Viewing the missing values % for each feature
df_mv = mvDF(df)
df_mv
# Out:
#                TotalMissing  PercentageMissing
# MSSubClass                0                0.0
# MSZoning                  0                0.0
# LotFrontage               0                0.0
# LotArea                   0                0.0
# Street                    0                0.0
# Alley                     0                0.0
# LotShape                  0                0.0
# LandContour               0                0.0
# Utilities                 0                0.0
# LotConfig                 0                0.0
# LandSlope                 0                0.0
# Neighborhood              0                0.0
# Condition1                0                0.0
# Condition2                0                0.0
# BldgType                  0                0.0
# HouseStyle                0                0.0
# OverallQual               0                0.0
# OverallCond               0                0.0
# YearBuilt                 0                0.0
# ...

# %%
df.to_csv(r'C:\Users\Ben\Desktop\Data Science\Kaggle\Advanced House Price Prediction\Dreprocessed_data\cleaned_mv.csv')
